# %% [markdown]
# <a href="https://colab.research.google.com/github/JJC-afk/mmWave-Radar-CNN-Fall-Detection/blob/main/finalproject_team7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/Shareddrives/FinalProject_446/BP-CNN-PyTorch-Team7
# Out:
# /content/drive/Shareddrives/FinalProject_446/BP-CNN-PyTorch-Team7

# %%
# %cd /content/drive/Shareddrives/FinalProject_446/BP-CNN-Tensorflow-Team7
# Out:
# /content/drive/Shareddrives/FinalProject_446/BP-CNN-Tensorflow-Team7

# %%
# !python3 main.py -Func Train
# Out:
# Function is set to Train
# Construct the data IO class for training!
#
# Loading model from ./model/netid0_model0/model.pth
# Test loss: 0.404281, orig loss: 2965.611598
# Iteration	Loss
# 500
# 0.23409397900104523
# 1000
# 0.22567459444204965
# 1500
# 0.22211649815241497
# 2000
# 0.21856741954882938
# Save 4 layers.
#
# Final minimum loss: 0.218567
# Used time for training: 14s
# Delete the data IO class!

# %%
# %%bash
# for val in 0.5 0.6 0.7 0.8 0.9 1.0
# do
#     echo "Running simulation for CorrPara: $val"
#     python3 main.py -Func Simulation -SimuCorrPara $val
# done
# Out:
# Running simulation for CorrPara: 0.5
# Function is set to Simulation
# Corr para for simulation is set to 0.50
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 37s
# end
#
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.00
# Batch 1 in total 47 batches. Practical EbN0: -0.00
# Batch 2 in total 47 batches. Practical EbN0: 0.00
# Batch 3 in total 47 batches. Practical EbN0: -0.00
# Batch 4 in total 47 batches. Practical EbN0: 0.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.50
# Batch 1 in total 47 batches. Practical EbN0: 0.50
# Batch 2 in total 47 batches. Practical EbN0: 0.50
# Batch 3 in total 47 batches. Practical EbN0: 0.50
# Batch 4 in total 47 batches. Practical EbN0: 0.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.00
# Batch 1 in total 47 batches. Practical EbN0: 1.00
# Batch 2 in total 47 batches. Practical EbN0: 1.00
# Batch 3 in total 47 batches. Practical EbN0: 1.00
# Batch 4 in total 47 batches. Practical EbN0: 1.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.50
# Batch 1 in total 47 batches. Practical EbN0: 1.50
# Batch 2 in total 47 batches. Practical EbN0: 1.50
# Batch 3 in total 47 batches. Practical EbN0: 1.50
# Batch 4 in total 47 batches. Practical EbN0: 1.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.00
# Batch 1 in total 47 batches. Practical EbN0: 2.00
# Batch 2 in total 47 batches. Practical EbN0: 2.00
# Batch 3 in total 47 batches. Practical EbN0: 2.00
# Batch 4 in total 47 batches. Practical EbN0: 2.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.50
# Batch 1 in total 47 batches. Practical EbN0: 2.50
# Batch 2 in total 47 batches. Practical EbN0: 2.50
# Batch 3 in total 47 batches. Practical EbN0: 2.50
# Batch 4 in total 47 batches. Practical EbN0: 2.50
# Batch 5 in total 47 batches. Practical EbN0: 2.50
# Batch 6 in total 47 batches. Practical EbN0: 2.50
# Batch 7 in total 47 batches. Practical EbN0: 2.51
# Batch 8 in total 47 batches. Practical EbN0: 2.50
# Batch 9 in total 47 batches. Practical EbN0: 2.50
# Batch 10 in total 47 batches. Practical EbN0: 2.50
# Batch 11 in total 47 batches. Practical EbN0: 2.50
# Batch 12 in total 47 batches. Practical EbN0: 2.49
# Batch 13 in total 47 batches. Practical EbN0: 2.50
# Batch 14 in total 47 batches. Practical EbN0: 2.50
# Batch 15 in total 47 batches. Practical EbN0: 2.50
# Batch 16 in total 47 batches. Practical EbN0: 2.51
# Batch 17 in total 47 batches. Practical EbN0: 2.50
# 38880000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.00
# Batch 1 in total 47 batches. Practical EbN0: 3.00
# Batch 2 in total 47 batches. Practical EbN0: 3.00
# Batch 3 in total 47 batches. Practical EbN0: 3.00
# Batch 4 in total 47 batches. Practical EbN0: 3.00
# Batch 5 in total 47 batches. Practical EbN0: 3.00
# Batch 6 in total 47 batches. Practical EbN0: 3.00
# Batch 7 in total 47 batches. Practical EbN0: 3.01
# Batch 8 in total 47 batches. Practical EbN0: 3.00
# Batch 9 in total 47 batches. Practical EbN0: 3.00
# Batch 10 in total 47 batches. Practical EbN0: 3.00
# Batch 11 in total 47 batches. Practical EbN0: 3.00
# Batch 12 in total 47 batches. Practical EbN0: 2.99
# Batch 13 in total 47 batches. Practical EbN0: 3.00
# Batch 14 in total 47 batches. Practical EbN0: 3.00
# Batch 15 in total 47 batches. Practical EbN0: 3.00
# Batch 16 in total 47 batches. Practical EbN0: 3.01
# Batch 17 in total 47 batches. Practical EbN0: 3.00
# Batch 18 in total 47 batches. Practical EbN0: 3.00
# Batch 19 in total 47 batches. Practical EbN0: 3.01
# Batch 20 in total 47 batches. Practical EbN0: 3.00
# Batch 21 in total 47 batches. Practical EbN0: 3.00
# Batch 22 in total 47 batches. Practical EbN0: 3.00
# Batch 23 in total 47 batches. Practical EbN0: 3.01
# Batch 24 in total 47 batches. Practical EbN0: 3.00
# Batch 25 in total 47 batches. Practical EbN0: 3.00
# Batch 26 in total 47 batches. Practical EbN0: 3.00
# Batch 27 in total 47 batches. Practical EbN0: 3.00
# Batch 28 in total 47 batches. Practical EbN0: 3.00
# Batch 29 in total 47 batches. Practical EbN0: 2.99
# Batch 30 in total 47 batches. Practical EbN0: 3.01
# Batch 31 in total 47 batches. Practical EbN0: 3.00
# Batch 32 in total 47 batches. Practical EbN0: 2.99
# Batch 33 in total 47 batches. Practical EbN0: 2.99
# Batch 34 in total 47 batches. Practical EbN0: 3.00
# Batch 35 in total 47 batches. Practical EbN0: 2.99
# Batch 36 in total 47 batches. Practical EbN0: 3.00
# Batch 37 in total 47 batches. Practical EbN0: 3.01
# Batch 38 in total 47 batches. Practical EbN0: 3.00
# Batch 39 in total 47 batches. Practical EbN0: 3.00
# Batch 40 in total 47 batches. Practical EbN0: 3.00
# Batch 41 in total 47 batches. Practical EbN0: 3.00
# Batch 42 in total 47 batches. Practical EbN0: 2.99
# Batch 43 in total 47 batches. Practical EbN0: 3.00
# Batch 44 in total 47 batches. Practical EbN0: 3.00
# Batch 45 in total 47 batches. Practical EbN0: 3.01
# Batch 46 in total 47 batches. Practical EbN0: 3.00
# 101520000 bits are simulated!
# Time: 159s
# end
#
# Running simulation for CorrPara: 0.6
# Function is set to Simulation
# Corr para for simulation is set to 0.60
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 37s
# end
#
# Correlation function of channel noise:
# [1.         0.59999996 0.35999998 0.216      0.12959997 0.07776001
#  0.04665599 0.0279936  0.01679616 0.0100777 ]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.00
# Batch 1 in total 47 batches. Practical EbN0: -0.00
# Batch 2 in total 47 batches. Practical EbN0: 0.00
# Batch 3 in total 47 batches. Practical EbN0: -0.00
# Batch 4 in total 47 batches. Practical EbN0: -0.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.50
# Batch 1 in total 47 batches. Practical EbN0: 0.50
# Batch 2 in total 47 batches. Practical EbN0: 0.50
# Batch 3 in total 47 batches. Practical EbN0: 0.50
# Batch 4 in total 47 batches. Practical EbN0: 0.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.00
# Batch 1 in total 47 batches. Practical EbN0: 1.00
# Batch 2 in total 47 batches. Practical EbN0: 1.00
# Batch 3 in total 47 batches. Practical EbN0: 1.00
# Batch 4 in total 47 batches. Practical EbN0: 1.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.50
# Batch 1 in total 47 batches. Practical EbN0: 1.50
# Batch 2 in total 47 batches. Practical EbN0: 1.50
# Batch 3 in total 47 batches. Practical EbN0: 1.50
# Batch 4 in total 47 batches. Practical EbN0: 1.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.00
# Batch 1 in total 47 batches. Practical EbN0: 2.00
# Batch 2 in total 47 batches. Practical EbN0: 2.00
# Batch 3 in total 47 batches. Practical EbN0: 2.00
# Batch 4 in total 47 batches. Practical EbN0: 2.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.50
# Batch 1 in total 47 batches. Practical EbN0: 2.50
# Batch 2 in total 47 batches. Practical EbN0: 2.50
# Batch 3 in total 47 batches. Practical EbN0: 2.50
# Batch 4 in total 47 batches. Practical EbN0: 2.50
# Batch 5 in total 47 batches. Practical EbN0: 2.50
# Batch 6 in total 47 batches. Practical EbN0: 2.50
# Batch 7 in total 47 batches. Practical EbN0: 2.51
# Batch 8 in total 47 batches. Practical EbN0: 2.50
# Batch 9 in total 47 batches. Practical EbN0: 2.51
# Batch 10 in total 47 batches. Practical EbN0: 2.50
# Batch 11 in total 47 batches. Practical EbN0: 2.51
# Batch 12 in total 47 batches. Practical EbN0: 2.49
# Batch 13 in total 47 batches. Practical EbN0: 2.50
# Batch 14 in total 47 batches. Practical EbN0: 2.49
# Batch 15 in total 47 batches. Practical EbN0: 2.50
# Batch 16 in total 47 batches. Practical EbN0: 2.51
# Batch 17 in total 47 batches. Practical EbN0: 2.50
# Batch 18 in total 47 batches. Practical EbN0: 2.50
# Batch 19 in total 47 batches. Practical EbN0: 2.51
# Batch 20 in total 47 batches. Practical EbN0: 2.50
# Batch 21 in total 47 batches. Practical EbN0: 2.50
# Batch 22 in total 47 batches. Practical EbN0: 2.50
# Batch 23 in total 47 batches. Practical EbN0: 2.51
# Batch 24 in total 47 batches. Practical EbN0: 2.50
# Batch 25 in total 47 batches. Practical EbN0: 2.50
# Batch 26 in total 47 batches. Practical EbN0: 2.51
# Batch 27 in total 47 batches. Practical EbN0: 2.50
# 60480000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.00
# Batch 1 in total 47 batches. Practical EbN0: 3.00
# Batch 2 in total 47 batches. Practical EbN0: 3.00
# Batch 3 in total 47 batches. Practical EbN0: 3.00
# Batch 4 in total 47 batches. Practical EbN0: 3.00
# Batch 5 in total 47 batches. Practical EbN0: 3.00
# Batch 6 in total 47 batches. Practical EbN0: 3.00
# Batch 7 in total 47 batches. Practical EbN0: 3.01
# Batch 8 in total 47 batches. Practical EbN0: 3.00
# Batch 9 in total 47 batches. Practical EbN0: 3.01
# Batch 10 in total 47 batches. Practical EbN0: 3.00
# Batch 11 in total 47 batches. Practical EbN0: 3.01
# Batch 12 in total 47 batches. Practical EbN0: 2.99
# Batch 13 in total 47 batches. Practical EbN0: 3.00
# Batch 14 in total 47 batches. Practical EbN0: 2.99
# Batch 15 in total 47 batches. Practical EbN0: 3.00
# Batch 16 in total 47 batches. Practical EbN0: 3.01
# Batch 17 in total 47 batches. Practical EbN0: 3.00
# Batch 18 in total 47 batches. Practical EbN0: 3.00
# Batch 19 in total 47 batches. Practical EbN0: 3.01
# Batch 20 in total 47 batches. Practical EbN0: 3.00
# Batch 21 in total 47 batches. Practical EbN0: 3.00
# Batch 22 in total 47 batches. Practical EbN0: 3.00
# Batch 23 in total 47 batches. Practical EbN0: 3.01
# Batch 24 in total 47 batches. Practical EbN0: 3.00
# Batch 25 in total 47 batches. Practical EbN0: 3.00
# Batch 26 in total 47 batches. Practical EbN0: 3.01
# Batch 27 in total 47 batches. Practical EbN0: 3.00
# Batch 28 in total 47 batches. Practical EbN0: 3.01
# Batch 29 in total 47 batches. Practical EbN0: 2.99
# Batch 30 in total 47 batches. Practical EbN0: 3.01
# Batch 31 in total 47 batches. Practical EbN0: 3.00
# Batch 32 in total 47 batches. Practical EbN0: 2.99
# Batch 33 in total 47 batches. Practical EbN0: 2.99
# Batch 34 in total 47 batches. Practical EbN0: 3.01
# Batch 35 in total 47 batches. Practical EbN0: 2.99
# Batch 36 in total 47 batches. Practical EbN0: 2.99
# Batch 37 in total 47 batches. Practical EbN0: 3.01
# Batch 38 in total 47 batches. Practical EbN0: 3.00
# Batch 39 in total 47 batches. Practical EbN0: 3.00
# Batch 40 in total 47 batches. Practical EbN0: 3.00
# Batch 41 in total 47 batches. Practical EbN0: 3.00
# Batch 42 in total 47 batches. Practical EbN0: 2.99
# Batch 43 in total 47 batches. Practical EbN0: 3.00
# Batch 44 in total 47 batches. Practical EbN0: 3.00
# Batch 45 in total 47 batches. Practical EbN0: 3.01
# Batch 46 in total 47 batches. Practical EbN0: 3.00
# 101520000 bits are simulated!
# Time: 181s
# end
#
# Running simulation for CorrPara: 0.7
# Function is set to Simulation
# Corr para for simulation is set to 0.70
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 37s
# end
#
# Correlation function of channel noise:
# [1.         0.70000005 0.48999995 0.34299994 0.24010003 0.16807003
#  0.11764901 0.0823543  0.05764802 0.04035361]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.01
# Batch 1 in total 47 batches. Practical EbN0: -0.01
# Batch 2 in total 47 batches. Practical EbN0: 0.00
# Batch 3 in total 47 batches. Practical EbN0: -0.01
# Batch 4 in total 47 batches. Practical EbN0: -0.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.51
# Batch 1 in total 47 batches. Practical EbN0: 0.49
# Batch 2 in total 47 batches. Practical EbN0: 0.50
# Batch 3 in total 47 batches. Practical EbN0: 0.49
# Batch 4 in total 47 batches. Practical EbN0: 0.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.01
# Batch 1 in total 47 batches. Practical EbN0: 0.99
# Batch 2 in total 47 batches. Practical EbN0: 1.00
# Batch 3 in total 47 batches. Practical EbN0: 0.99
# Batch 4 in total 47 batches. Practical EbN0: 1.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.51
# Batch 1 in total 47 batches. Practical EbN0: 1.49
# Batch 2 in total 47 batches. Practical EbN0: 1.50
# Batch 3 in total 47 batches. Practical EbN0: 1.49
# Batch 4 in total 47 batches. Practical EbN0: 1.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.01
# Batch 1 in total 47 batches. Practical EbN0: 1.99
# Batch 2 in total 47 batches. Practical EbN0: 2.00
# Batch 3 in total 47 batches. Practical EbN0: 1.99
# Batch 4 in total 47 batches. Practical EbN0: 2.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.51
# Batch 1 in total 47 batches. Practical EbN0: 2.49
# Batch 2 in total 47 batches. Practical EbN0: 2.50
# Batch 3 in total 47 batches. Practical EbN0: 2.49
# Batch 4 in total 47 batches. Practical EbN0: 2.50
# Batch 5 in total 47 batches. Practical EbN0: 2.50
# Batch 6 in total 47 batches. Practical EbN0: 2.50
# Batch 7 in total 47 batches. Practical EbN0: 2.51
# Batch 8 in total 47 batches. Practical EbN0: 2.50
# Batch 9 in total 47 batches. Practical EbN0: 2.51
# Batch 10 in total 47 batches. Practical EbN0: 2.49
# Batch 11 in total 47 batches. Practical EbN0: 2.51
# Batch 12 in total 47 batches. Practical EbN0: 2.49
# Batch 13 in total 47 batches. Practical EbN0: 2.50
# Batch 14 in total 47 batches. Practical EbN0: 2.49
# Batch 15 in total 47 batches. Practical EbN0: 2.50
# Batch 16 in total 47 batches. Practical EbN0: 2.51
# Batch 17 in total 47 batches. Practical EbN0: 2.50
# Batch 18 in total 47 batches. Practical EbN0: 2.50
# Batch 19 in total 47 batches. Practical EbN0: 2.51
# Batch 20 in total 47 batches. Practical EbN0: 2.49
# Batch 21 in total 47 batches. Practical EbN0: 2.50
# Batch 22 in total 47 batches. Practical EbN0: 2.50
# Batch 23 in total 47 batches. Practical EbN0: 2.50
# Batch 24 in total 47 batches. Practical EbN0: 2.50
# Batch 25 in total 47 batches. Practical EbN0: 2.50
# Batch 26 in total 47 batches. Practical EbN0: 2.50
# Batch 27 in total 47 batches. Practical EbN0: 2.50
# 60480000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.01
# Batch 1 in total 47 batches. Practical EbN0: 2.99
# Batch 2 in total 47 batches. Practical EbN0: 3.00
# Batch 3 in total 47 batches. Practical EbN0: 2.99
# Batch 4 in total 47 batches. Practical EbN0: 3.00
# Batch 5 in total 47 batches. Practical EbN0: 3.00
# Batch 6 in total 47 batches. Practical EbN0: 3.00
# Batch 7 in total 47 batches. Practical EbN0: 3.01
# Batch 8 in total 47 batches. Practical EbN0: 3.00
# Batch 9 in total 47 batches. Practical EbN0: 3.01
# Batch 10 in total 47 batches. Practical EbN0: 2.99
# Batch 11 in total 47 batches. Practical EbN0: 3.01
# Batch 12 in total 47 batches. Practical EbN0: 2.99
# Batch 13 in total 47 batches. Practical EbN0: 3.00
# Batch 14 in total 47 batches. Practical EbN0: 2.99
# Batch 15 in total 47 batches. Practical EbN0: 3.00
# Batch 16 in total 47 batches. Practical EbN0: 3.01
# Batch 17 in total 47 batches. Practical EbN0: 3.00
# Batch 18 in total 47 batches. Practical EbN0: 3.00
# Batch 19 in total 47 batches. Practical EbN0: 3.01
# Batch 20 in total 47 batches. Practical EbN0: 2.99
# Batch 21 in total 47 batches. Practical EbN0: 3.00
# Batch 22 in total 47 batches. Practical EbN0: 3.00
# Batch 23 in total 47 batches. Practical EbN0: 3.00
# Batch 24 in total 47 batches. Practical EbN0: 3.00
# Batch 25 in total 47 batches. Practical EbN0: 3.00
# Batch 26 in total 47 batches. Practical EbN0: 3.00
# Batch 27 in total 47 batches. Practical EbN0: 3.00
# Batch 28 in total 47 batches. Practical EbN0: 3.01
# Batch 29 in total 47 batches. Practical EbN0: 2.99
# Batch 30 in total 47 batches. Practical EbN0: 3.02
# Batch 31 in total 47 batches. Practical EbN0: 3.00
# Batch 32 in total 47 batches. Practical EbN0: 2.99
# Batch 33 in total 47 batches. Practical EbN0: 2.99
# Batch 34 in total 47 batches. Practical EbN0: 3.01
# Batch 35 in total 47 batches. Practical EbN0: 2.99
# Batch 36 in total 47 batches. Practical EbN0: 2.99
# Batch 37 in total 47 batches. Practical EbN0: 3.01
# Batch 38 in total 47 batches. Practical EbN0: 3.00
# Batch 39 in total 47 batches. Practical EbN0: 2.99
# Batch 40 in total 47 batches. Practical EbN0: 3.00
# Batch 41 in total 47 batches. Practical EbN0: 3.00
# Batch 42 in total 47 batches. Practical EbN0: 2.99
# Batch 43 in total 47 batches. Practical EbN0: 3.00
# Batch 44 in total 47 batches. Practical EbN0: 3.01
# Batch 45 in total 47 batches. Practical EbN0: 3.01
# Batch 46 in total 47 batches. Practical EbN0: 3.01
# 101520000 bits are simulated!
# Time: 177s
# end
#
# Running simulation for CorrPara: 0.8
# Function is set to Simulation
# Corr para for simulation is set to 0.80
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 38s
# end
#
# Correlation function of channel noise:
# [0.99999976 0.79999995 0.6399999  0.51199967 0.40959996 0.32768005
#  0.26214397 0.20971522 0.16777213 0.13421775]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.01
# Batch 1 in total 47 batches. Practical EbN0: -0.01
# Batch 2 in total 47 batches. Practical EbN0: 0.00
# Batch 3 in total 47 batches. Practical EbN0: -0.01
# Batch 4 in total 47 batches. Practical EbN0: -0.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.51
# Batch 1 in total 47 batches. Practical EbN0: 0.49
# Batch 2 in total 47 batches. Practical EbN0: 0.50
# Batch 3 in total 47 batches. Practical EbN0: 0.49
# Batch 4 in total 47 batches. Practical EbN0: 0.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.01
# Batch 1 in total 47 batches. Practical EbN0: 0.99
# Batch 2 in total 47 batches. Practical EbN0: 1.00
# Batch 3 in total 47 batches. Practical EbN0: 0.99
# Batch 4 in total 47 batches. Practical EbN0: 1.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.51
# Batch 1 in total 47 batches. Practical EbN0: 1.49
# Batch 2 in total 47 batches. Practical EbN0: 1.50
# Batch 3 in total 47 batches. Practical EbN0: 1.49
# Batch 4 in total 47 batches. Practical EbN0: 1.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.01
# Batch 1 in total 47 batches. Practical EbN0: 1.99
# Batch 2 in total 47 batches. Practical EbN0: 2.00
# Batch 3 in total 47 batches. Practical EbN0: 1.99
# Batch 4 in total 47 batches. Practical EbN0: 2.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.51
# Batch 1 in total 47 batches. Practical EbN0: 2.49
# Batch 2 in total 47 batches. Practical EbN0: 2.50
# Batch 3 in total 47 batches. Practical EbN0: 2.49
# Batch 4 in total 47 batches. Practical EbN0: 2.50
# Batch 5 in total 47 batches. Practical EbN0: 2.50
# Batch 6 in total 47 batches. Practical EbN0: 2.50
# Batch 7 in total 47 batches. Practical EbN0: 2.52
# Batch 8 in total 47 batches. Practical EbN0: 2.50
# Batch 9 in total 47 batches. Practical EbN0: 2.51
# Batch 10 in total 47 batches. Practical EbN0: 2.49
# Batch 11 in total 47 batches. Practical EbN0: 2.51
# Batch 12 in total 47 batches. Practical EbN0: 2.49
# Batch 13 in total 47 batches. Practical EbN0: 2.50
# Batch 14 in total 47 batches. Practical EbN0: 2.49
# Batch 15 in total 47 batches. Practical EbN0: 2.50
# Batch 16 in total 47 batches. Practical EbN0: 2.51
# Batch 17 in total 47 batches. Practical EbN0: 2.50
# Batch 18 in total 47 batches. Practical EbN0: 2.50
# Batch 19 in total 47 batches. Practical EbN0: 2.51
# Batch 20 in total 47 batches. Practical EbN0: 2.49
# 45360000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.01
# Batch 1 in total 47 batches. Practical EbN0: 2.99
# Batch 2 in total 47 batches. Practical EbN0: 3.00
# Batch 3 in total 47 batches. Practical EbN0: 2.99
# Batch 4 in total 47 batches. Practical EbN0: 3.00
# Batch 5 in total 47 batches. Practical EbN0: 3.00
# Batch 6 in total 47 batches. Practical EbN0: 3.00
# Batch 7 in total 47 batches. Practical EbN0: 3.02
# Batch 8 in total 47 batches. Practical EbN0: 3.00
# Batch 9 in total 47 batches. Practical EbN0: 3.01
# Batch 10 in total 47 batches. Practical EbN0: 2.99
# Batch 11 in total 47 batches. Practical EbN0: 3.01
# Batch 12 in total 47 batches. Practical EbN0: 2.99
# Batch 13 in total 47 batches. Practical EbN0: 3.00
# Batch 14 in total 47 batches. Practical EbN0: 2.99
# Batch 15 in total 47 batches. Practical EbN0: 3.00
# Batch 16 in total 47 batches. Practical EbN0: 3.01
# Batch 17 in total 47 batches. Practical EbN0: 3.00
# Batch 18 in total 47 batches. Practical EbN0: 3.00
# Batch 19 in total 47 batches. Practical EbN0: 3.01
# Batch 20 in total 47 batches. Practical EbN0: 2.99
# Batch 21 in total 47 batches. Practical EbN0: 2.99
# Batch 22 in total 47 batches. Practical EbN0: 3.00
# Batch 23 in total 47 batches. Practical EbN0: 3.00
# Batch 24 in total 47 batches. Practical EbN0: 3.00
# Batch 25 in total 47 batches. Practical EbN0: 2.99
# Batch 26 in total 47 batches. Practical EbN0: 3.00
# Batch 27 in total 47 batches. Practical EbN0: 3.00
# Batch 28 in total 47 batches. Practical EbN0: 3.01
# Batch 29 in total 47 batches. Practical EbN0: 2.99
# Batch 30 in total 47 batches. Practical EbN0: 3.02
# Batch 31 in total 47 batches. Practical EbN0: 2.99
# Batch 32 in total 47 batches. Practical EbN0: 2.99
# Batch 33 in total 47 batches. Practical EbN0: 2.99
# Batch 34 in total 47 batches. Practical EbN0: 3.01
# Batch 35 in total 47 batches. Practical EbN0: 2.98
# Batch 36 in total 47 batches. Practical EbN0: 2.99
# Batch 37 in total 47 batches. Practical EbN0: 3.00
# Batch 38 in total 47 batches. Practical EbN0: 3.00
# Batch 39 in total 47 batches. Practical EbN0: 2.99
# Batch 40 in total 47 batches. Practical EbN0: 3.00
# Batch 41 in total 47 batches. Practical EbN0: 3.00
# Batch 42 in total 47 batches. Practical EbN0: 2.99
# Batch 43 in total 47 batches. Practical EbN0: 2.99
# Batch 44 in total 47 batches. Practical EbN0: 3.01
# Batch 45 in total 47 batches. Practical EbN0: 3.00
# Batch 46 in total 47 batches. Practical EbN0: 3.01
# 101520000 bits are simulated!
# Time: 161s
# end
#
# Running simulation for CorrPara: 0.9
# Function is set to Simulation
# Corr para for simulation is set to 0.90
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 37s
# end
#
# Correlation function of channel noise:
# [0.9999999  0.89999986 0.81000006 0.7289998  0.6560999  0.5904899
#  0.531441   0.47829688 0.43046713 0.38742062]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.01
# Batch 1 in total 47 batches. Practical EbN0: -0.02
# Batch 2 in total 47 batches. Practical EbN0: 0.00
# Batch 3 in total 47 batches. Practical EbN0: -0.01
# Batch 4 in total 47 batches. Practical EbN0: 0.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.51
# Batch 1 in total 47 batches. Practical EbN0: 0.48
# Batch 2 in total 47 batches. Practical EbN0: 0.50
# Batch 3 in total 47 batches. Practical EbN0: 0.49
# Batch 4 in total 47 batches. Practical EbN0: 0.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.01
# Batch 1 in total 47 batches. Practical EbN0: 0.98
# Batch 2 in total 47 batches. Practical EbN0: 1.00
# Batch 3 in total 47 batches. Practical EbN0: 0.99
# Batch 4 in total 47 batches. Practical EbN0: 1.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.51
# Batch 1 in total 47 batches. Practical EbN0: 1.48
# Batch 2 in total 47 batches. Practical EbN0: 1.50
# Batch 3 in total 47 batches. Practical EbN0: 1.49
# Batch 4 in total 47 batches. Practical EbN0: 1.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.01
# Batch 1 in total 47 batches. Practical EbN0: 1.98
# Batch 2 in total 47 batches. Practical EbN0: 2.00
# Batch 3 in total 47 batches. Practical EbN0: 1.99
# Batch 4 in total 47 batches. Practical EbN0: 2.00
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.51
# Batch 1 in total 47 batches. Practical EbN0: 2.48
# Batch 2 in total 47 batches. Practical EbN0: 2.50
# Batch 3 in total 47 batches. Practical EbN0: 2.49
# Batch 4 in total 47 batches. Practical EbN0: 2.50
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.01
# Batch 1 in total 47 batches. Practical EbN0: 2.98
# Batch 2 in total 47 batches. Practical EbN0: 3.00
# Batch 3 in total 47 batches. Practical EbN0: 2.99
# Batch 4 in total 47 batches. Practical EbN0: 3.00
# Batch 5 in total 47 batches. Practical EbN0: 3.00
# Batch 6 in total 47 batches. Practical EbN0: 3.00
# Batch 7 in total 47 batches. Practical EbN0: 3.03
# Batch 8 in total 47 batches. Practical EbN0: 3.00
# Batch 9 in total 47 batches. Practical EbN0: 3.02
# Batch 10 in total 47 batches. Practical EbN0: 2.99
# Batch 11 in total 47 batches. Practical EbN0: 3.01
# Batch 12 in total 47 batches. Practical EbN0: 2.98
# Batch 13 in total 47 batches. Practical EbN0: 3.00
# Batch 14 in total 47 batches. Practical EbN0: 2.98
# Batch 15 in total 47 batches. Practical EbN0: 3.01
# Batch 16 in total 47 batches. Practical EbN0: 3.02
# Batch 17 in total 47 batches. Practical EbN0: 2.99
# Batch 18 in total 47 batches. Practical EbN0: 3.00
# Batch 19 in total 47 batches. Practical EbN0: 3.02
# Batch 20 in total 47 batches. Practical EbN0: 2.99
# Batch 21 in total 47 batches. Practical EbN0: 2.99
# Batch 22 in total 47 batches. Practical EbN0: 3.01
# Batch 23 in total 47 batches. Practical EbN0: 2.99
# Batch 24 in total 47 batches. Practical EbN0: 3.00
# Batch 25 in total 47 batches. Practical EbN0: 2.99
# Batch 26 in total 47 batches. Practical EbN0: 3.00
# Batch 27 in total 47 batches. Practical EbN0: 3.00
# Batch 28 in total 47 batches. Practical EbN0: 3.01
# Batch 29 in total 47 batches. Practical EbN0: 2.98
# Batch 30 in total 47 batches. Practical EbN0: 3.02
# Batch 31 in total 47 batches. Practical EbN0: 2.99
# 69120000 bits are simulated!
# Time: 109s
# end
#
# Running simulation for CorrPara: 1.0
# Function is set to Simulation
# Corr para for simulation is set to 1.00
# Correlation function of channel noise:
# [1.         0.5        0.25000003 0.125      0.0625     0.03125
#  0.015625   0.0078125  0.00390625 0.00195313]
# Real simutimes: 15000
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Batch id: 0
# Batch id: 1
# Batch id: 2
# Time: 37s
# end
#
# Correlation function of channel noise:
# [0.99999726 0.99999726 0.99999726 0.99999726 0.99999726 0.99999726
#  0.99999726 0.99999726 0.99999726 0.99999726]
# Loading model from ./model/netid0_model0/model.pth
# Restore layers from checkpoint.
#
# Batch 0 in total 47 batches. Practical EbN0: 0.09
# Batch 1 in total 47 batches. Practical EbN0: 0.08
# Batch 2 in total 47 batches. Practical EbN0: -0.07
# Batch 3 in total 47 batches. Practical EbN0: -0.04
# Batch 4 in total 47 batches. Practical EbN0: 0.20
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 0.59
# Batch 1 in total 47 batches. Practical EbN0: 0.58
# Batch 2 in total 47 batches. Practical EbN0: 0.43
# Batch 3 in total 47 batches. Practical EbN0: 0.46
# Batch 4 in total 47 batches. Practical EbN0: 0.70
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.09
# Batch 1 in total 47 batches. Practical EbN0: 1.08
# Batch 2 in total 47 batches. Practical EbN0: 0.93
# Batch 3 in total 47 batches. Practical EbN0: 0.96
# Batch 4 in total 47 batches. Practical EbN0: 1.20
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 1.59
# Batch 1 in total 47 batches. Practical EbN0: 1.58
# Batch 2 in total 47 batches. Practical EbN0: 1.43
# Batch 3 in total 47 batches. Practical EbN0: 1.46
# Batch 4 in total 47 batches. Practical EbN0: 1.70
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.09
# Batch 1 in total 47 batches. Practical EbN0: 2.08
# Batch 2 in total 47 batches. Practical EbN0: 1.93
# Batch 3 in total 47 batches. Practical EbN0: 1.96
# Batch 4 in total 47 batches. Practical EbN0: 2.20
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 2.59
# Batch 1 in total 47 batches. Practical EbN0: 2.58
# Batch 2 in total 47 batches. Practical EbN0: 2.43
# Batch 3 in total 47 batches. Practical EbN0: 2.46
# Batch 4 in total 47 batches. Practical EbN0: 2.70
# 10800000 bits are simulated!
# Batch 0 in total 47 batches. Practical EbN0: 3.09
# Batch 1 in total 47 batches. Practical EbN0: 3.08
# Batch 2 in total 47 batches. Practical EbN0: 2.93
# Batch 3 in total 47 batches. Practical EbN0: 2.96
# Batch 4 in total 47 batches. Practical EbN0: 3.20
# 10800000 bits are simulated!
# Time: 61s
# end
